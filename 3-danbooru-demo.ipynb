# %%
import torch
import torch.nn as nn
import numpy as np
import torchvision
from torchvision import models
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image

# %% [markdown]
# ### Data Prep

# %%
img_data_dir = "/media/curttigges/project-files/datasets/danbooru/"

# %% [markdown]
# #### Data Examination

# %%
df = pd.read_pickle(img_data_dir+'image_subset_metadata.pkl')
dfs = df.sample(50000)
dfs.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_8839/2819427851.py in <module>
# ----> 1 df = pd.read_pickle(img_data_dir+'image_subset_metadata.pkl')
#       2 dfs = df.sample(50000)
#       3 dfs.head()
#
# ~/miniconda3/envs/pytorch-dl/lib/python3.7/site-packages/pandas/io/pickle.py in read_pickle(filepath_or_buffer, compression, storage_options)
#     199         compression=compression,
#     200         is_text=False,
# --> 201         storage_options=storage_options,
#     202     ) as handles:
#     203
#
# ~/miniconda3/envs/pytorch-dl/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# FileNotFoundError: [Errno 2] No such file or directory: '/media/curttigges/project-files/datasets/danbooru/image_subset_metadata.pkl'

# %%
im = Image.open(img_data_dir+dfs.iloc[5,3])
im
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_8839/3881372324.py in <module>
# ----> 1 im = Image.open(img_data_dir+dfs.iloc[5,3])
#       2 im
#
# NameError: name 'dfs' is not defined

# %%
im.size
# Out:
# (512, 512)

# %%
dfs.head()
# Out:
#              id                                               tags  \
# 8888     688054  [{'id': '540830', 'name': '1boy', 'category': ...
# 65854    472091  [{'id': '470575', 'name': '1girl', 'category':...
# 46820    323114  [{'id': '540830', 'name': '1boy', 'category': ...
# 115006  2098014  [{'id': '1821', 'name': '2girls', 'category': ...
# 46134    235119  [{'id': '470575', 'name': '1girl', 'category':...
#
#         image_available                                             paths  \
# 8888                1.0   danbooru-images/danbooru-images/0054/688054.jpg
# 65854               1.0   danbooru-images/danbooru-images/0091/472091.jpg
# 46820               1.0   danbooru-images/danbooru-images/0114/323114.jpg
# 115006              1.0  danbooru-images/danbooru-images/0014/2098014.jpg
# 46134               1.0   danbooru-images/danbooru-images/0119/235119.jpg
#
#          file_names                                           tagslist
# 8888     688054.jpg  [1boy, 1girl, a-i-red, asbel_lhant, bad_id, ba...
# 65854    472091.jpg  [1girl, akudama_geku, blue_eyes, blue_hair, ca...
# 46820    323114.jpg  [1boy, 1girl, bad_id, bad_pixiv_id, bikini, bl...
# 115006  2098014.jpg  [2girls, alternate_costume, bat_wings, breasts...
# 46134    235119.jpg  [1girl, animal_ears, baku_taso, bunny_ears, ch...

# %%
def get_tag_dict(df, n=10):
    tag_dict = {}
    for list in df.tagslist:
        for tag in list:
            if tag in tag_dict:
                tag_dict[tag] += 1
            else:
                tag_dict[tag] = 1

    item = sorted(tag_dict.items(), key = lambda x:x[1],reverse = True)
    print(f"{n} top tags:")
    for i in range(0,n):
        print(item[i])

    return tag_dict

# %%
def get_top_tags(tag_dict, min_support):
    reduced_dict = {t for t in tag_dict if tag_dict[t] > min_support}
    print(f"Dictionary contains {len(reduced_dict)} tags.")
    tag_list = [l for l in reduced_dict]
    return tag_list

# %%
tags = get_tag_dict(dfs, 10)
classes = get_top_tags(tags, 100)
# Out:
# 10 top tags:
# ('1girl', 33055)
# ('solo', 28992)
# ('long_hair', 21941)
# ('highres', 16827)
# ('smile', 14957)
# ('short_hair', 14436)
# ('multiple_girls', 12173)
# ('blush', 11867)
# ('touhou', 10975)
# ('looking_at_viewer', 10757)
# Dictionary contains 1345 tags.

# %%
class_map = {n:c for n, c in enumerate(classes)}
class_map
# Out:
# {0: 'neptune_(series)',
#  1: 'bloomers',
#  2: 'check_translation',
#  3: 'detached_collar',
#  4: 'strapless_dress',
#  5: 'skirt',
#  6: 'wallpaper',
#  7: 'black_bow',
#  8: 'eyebrows',
#  9: 'mahou_shoujo_lyrical_nanoha_strikers',
#  10: 'artist_self-insert',
#  11: 'white_hair',
#  12: 'full_moon',
#  13: 'overwatch',
#  14: 'touken_ranbu',
#  15: 'halterneck',
#  16: 'green_background',
#  17: 'valentine',
#  18: 'animal_print',
#  19: 'faceless',
#  20: 'hood_down',
#  21: 'covering',
#  22: 'white_flower',
#  23: 'drooling',
#  24: 'cameltoe',
#  25: 'sign',
#  26: 'sitting',
#  27: 'witch_hat',
#  28: 'helmet',
#  29: 'shiny_hair',
#  30: 'headset',
#  31: 'red_neckwear',
#  32: 'kamishirasawa_keine',
#  33: 'tate_eboshi',
#  34: 'double_bun',
#  35: 'traditional_media',
#  36: 'brown_footwear',
#  37: 'pink_eyes',
#  38: 'name_tag',
#  39: 'rose',
#  40: 'back',
#  41: 'thighhighs',
#  42: 'side_braid',
#  43: 'guitar',
#  44: 'lolita_fashion',
#  45: 'dated',
#  46: 'visor_cap',
#  47: 'bow_(weapon)',
#  48: 'witch',
#  49: 'multiple_tails',
#  50: 'sisters',
#  51: 'tenryuu_(kantai_collection)',
#  52: 'hat',
#  53: 'bell',
#  54: '+++',
#  55: 'vertical_stripes',
#  56: 'bird',
#  57: 'eyes_visible_through_hair',
#  58: 'hakama_skirt',
#  59: 'holding_weapon',
#  60: 'hairpin',
#  61: 'mouth_hold',
#  62: 'military_hat',
#  63: 'pillow',
#  64: 'holding_book',
#  65: 'cloudy_sky',
#  66: 'adjusting_eyewear',
#  67: 'eating',
#  68: 'o_o',
#  69: 'mary_janes',
#  70: 'sharp_teeth',
#  71: 'outstretched_arms',
#  72: 'military',
#  73: 'low-tied_long_hair',
#  74: 'popsicle',
#  75: 'bad_twitter_id',
#  76: 'hair_bell',
#  77: 'thigh_gap',
#  78: 'sash',
#  79: 'military_uniform',
#  80: 'tears',
#  81: 'spoilers',
#  82: 'space',
#  83: 'ghost',
#  84: 'tress_ribbon',
#  85: 'spoken_ellipsis',
#  86: 'pokemon',
#  87: 'alcohol',
#  88: 'upskirt',
#  89: 'gauntlets',
#  90: 'mononobe_no_futo',
#  91: 'rifle',
#  92: 'red-framed_eyewear',
#  93: 'sword_art_online',
#  94: 'copyright_name',
#  95: 'tongue',
#  96: 'frog',
#  97: 'high_ponytail',
#  98: 'gap',
#  99: 'covered_navel',
#  100: 'kaga_(kantai_collection)',
#  101: 'neon_genesis_evangelion',
#  102: 'sleeveless',
#  103: 'armpits',
#  104: 'pistol',
#  105: 'finger_to_mouth',
#  106: 'crying_with_eyes_open',
#  107: 'running',
#  108: '2boys',
#  109: 'symbol-shaped_pupils',
#  110: 'commentary',
#  111: 'poke_ball',
#  112: 'string',
#  113: 'gothic_lolita',
#  114: 'highres',
#  115: 'sideboob',
#  116: 'twin_drills',
#  117: 'hands_together',
#  118: 'covered_nipples',
#  119: 'shiki_eiki',
#  120: 'striped_legwear',
#  121: 'fish',
#  122: 'tan',
#  123: 'chair',
#  124: 'necktie',
#  125: 'apron',
#  126: 'plate',
#  127: 'nurse_cap',
#  128: 'spoken_heart',
#  129: 'ass_visible_through_thighs',
#  130: 'black_panties',
#  131: 'mizuhashi_parsee',
#  132: 'headphones',
#  133: 'drinking_straw',
#  134: 'gun',
#  135: 'blue_bow',
#  136: 'folding_fan',
#  137: 'indoors',
#  138: 'basket',
#  139: 'miniskirt',
#  140: 'cross-laced_footwear',
#  141: 'mole_under_eye',
#  142: 'nosebleed',
#  143: 'impossible_clothes',
#  144: 'plant',
#  145: 'panties',
#  146: 'spot_color',
#  147: 'nazrin',
#  148: 'kantai_collection',
#  149: 'black_hat',
#  150: 'drink',
#  151: 'twintails',
#  152: 'danganronpa',
#  153: 'precure',
#  154: 'sparkle',
#  155: 'from_below',
#  156: ';d',
#  157: 'hooded_jacket',
#  158: 'girls_und_panzer',
#  159: 'fang',
#  160: 'detached_sleeves',
#  161: "mahou_shoujo_lyrical_nanoha_a's",
#  162: 'arms_behind_head',
#  163: 'buckle',
#  164: 'glowing',
#  165: 'holster',
#  166: 'injury',
#  167: 'mecha',
#  168: 'cloud',
#  169: 'clenched_teeth',
#  170: 'eyebrows_visible_through_hair',
#  171: '|_|',
#  172: 'admiral_(kantai_collection)',
#  173: 'alternate_costume',
#  174: 'garter_straps',
#  175: 'wind',
#  176: 'mirror',
#  177: 'looking_down',
#  178: 'long_sleeves',
#  179: 'labcoat',
#  180: 'glowing_eyes',
#  181: 'simple_background',
#  182: 'holding',
#  183: 'frown',
#  184: 'wriggle_nightbug',
#  185: 'eyepatch',
#  186: 'shigure_(kantai_collection)',
#  187: 'adjusting_hair',
#  188: 'juliet_sleeves',
#  189: 're:zero_kara_hajimeru_isekai_seikatsu',
#  190: 'floating',
#  191: 'hug_from_behind',
#  192: 'indian_style',
#  193: 'standing',
#  194: 'idolmaster_million_live!',
#  195: 'zoom_layer',
#  196: 'fangs',
#  197: 'tsurime',
#  198: 'streaked_hair',
#  199: 'saigyouji_yuyuko',
#  200: 'white_background',
#  201: 'orange_hair',
#  202: 'hair_over_one_eye',
#  203: 'coat',
#  204: 'wolf_ears',
#  205: 'idolmaster',
#  206: 'table',
#  207: 'christmas',
#  208: 'hips',
#  209: 'bunny_girl',
#  210: 'souryuu_asuka_langley',
#  211: 'child',
#  212: 'bad_id',
#  213: 'image_sample',
#  214: 'pajamas',
#  215: 'silent_comic',
#  216: 'road',
#  217: 'fur_trim',
#  218: 'splatoon',
#  219: 'petals',
#  220: 'smartphone',
#  221: 'nature',
#  222: 'blue_ribbon',
#  223: 'hair_bun',
#  224: 'otonokizaka_school_uniform',
#  225: 'swept_bangs',
#  226: 'closed_mouth',
#  227: 'outstretched_hand',
#  228: 'fingerless_gloves',
#  229: 'pink_skirt',
#  230: 'medium_breasts',
#  231: 'open_book',
#  232: 'arm_cannon',
#  233: 'loafers',
#  234: 'tassel',
#  235: 'mole_under_mouth',
#  236: 'tray',
#  237: 'vocaloid',
#  238: 'rensouhou-chan',
#  239: 'rain',
#  240: 'ocean',
#  241: 'huge_breasts',
#  242: 'hoshiguma_yuugi',
#  243: 'knife',
#  244: 'fubuki_(kantai_collection)',
#  245: 'abs',
#  246: 'reiuji_utsuho',
#  247: 'sun',
#  248: 'katana',
#  249: 'fate/stay_night',
#  250: 'between_legs',
#  251: 'blazblue',
#  252: 'top_hat',
#  253: 'striped_bikini',
#  254: 'upside-down',
#  255: 'bare_shoulders',
#  256: 'wet_clothes',
#  257: 'arm_at_side',
#  258: 'blazer',
#  259: 'original',
#  260: 'ahoge',
#  261: 'waist_apron',
#  262: 'yasaka_kanako',
#  263: 'instrument',
#  264: 'underwear_only',
#  265: 'silhouette',
#  266: 'frilled_dress',
#  267: 'jacket',
#  268: 'gradient',
#  269: 'border',
#  270: 'blue_hair',
#  271: 'mole',
#  272: 'lying',
#  273: 'red_ribbon',
#  274: '3girls',
#  275: 'eyes',
#  276: 'crescent',
#  277: 'butt_crack',
#  278: 'chinese',
#  279: 'red_hair',
#  280: 'wavy_hair',
#  281: 'dress_shirt',
#  282: 'short_twintails',
#  283: 'frills',
#  284: 'bag',
#  285: 'mouse_tail',
#  286: 'to_aru_majutsu_no_index',
#  287: 'crown',
#  288: 'cigarette',
#  289: 'frilled_sleeves',
#  290: 'empty_eyes',
#  291: 'pink_panties',
#  292: 'bracelet',
#  293: 'angel_wings',
#  294: 'genderswap_(mtf)',
#  295: 'k-on!',
#  296: 'white_skirt',
#  297: 'md5_mismatch',
#  298: 'magic',
#  299: 'everyone',
#  300: 'cuffs',
#  301: 'light_brown_hair',
#  302: 'crossdressing',
#  303: 'angry',
#  304: 'drinking',
#  305: 'yuudachi_(kantai_collection)',
#  306: 'white_dress',
#  307: 'akagi_(kantai_collection)',
#  308: 'strawberry',
#  309: 'sandals',
#  310: 'bandana',
#  311: 'underboob',
#  312: 'city',
#  313: 'plugsuit',
#  314: 'kirisame_marisa',
#  315: 'facial_mark',
#  316: 'pokemon_(game)',
#  317: 'handgun',
#  318: '=_=',
#  319: 'aircraft',
#  320: 'fence',
#  321: 'genderswap',
#  322: 'lips',
#  323: 'no_nose',
#  324: 'animal_ears',
#  325: 'frilled_skirt',
#  326: 'shaded_face',
#  327: 'gradient_background',
#  328: 'blush_stickers',
#  329: 'paws',
#  330: 'alternate_hair_length',
#  331: 'sleeping',
#  332: '1girl',
#  333: 'breath',
#  334: 'boots',
#  335: 'short_hair_with_long_locks',
#  336: 'light_smile',
#  337: 'fire_emblem',
#  338: 'profile',
#  339: 'snowflakes',
#  340: 'forehead_mark',
#  341: 'legs_together',
#  342: 'tomoe_mami',
#  343: 'naval_uniform',
#  344: 'no_pants',
#  345: 'holding_sword',
#  346: 'long_skirt',
#  347: 'water',
#  348: 'cowboy_shot',
#  349: 'blood_on_face',
#  350: 'foreshortening',
#  351: 'lucky_star',
#  352: 'sun_hat',
#  353: 'sleeves_past_wrists',
#  354: 'sidelocks',
#  355: 'siblings',
#  356: 'scarf',
#  357: 'floral_print',
#  358: 'spikes',
#  359: 'v_arms',
#  360: 'pointing',
#  361: 'tentacle_hair',
#  362: 'gundam',
#  363: 'ikazuchi_(kantai_collection)',
#  364: 'forest',
#  365: 'tabi',
#  366: 'green_eyes',
#  367: 'blouse',
#  368: 'pendant',
#  369: 'lollipop',
#  370: '4boys',
#  371: 'chocolate',
#  372: 'snowing',
#  373: 'shingeki_no_kyojin',
#  374: 'street_fighter',
#  375: 'japanese_armor',
#  376: 'blush',
#  377: 'hug',
#  378: 'rope',
#  379: 'knee_boots',
#  380: 'pantyshot_(sitting)',
#  381: 'front-tie_top',
#  382: 'black_bra',
#  383: 'pantyhose',
#  384: 'licking',
#  385: 'sunglasses',
#  386: 'ascot',
#  387: 'half_updo',
#  388: 'pencil_skirt',
#  389: 'short_sleeves',
#  390: 'no_headwear',
#  391: 'hands_up',
#  392: 'persona',
#  393: 'ice',
#  394: ':3',
#  395: 'skin_tight',
#  396: 'eyeball',
#  397: 'nose',
#  398: 'teeth',
#  399: 'black_neckwear',
#  400: 'gloves',
#  401: 'white_panties',
#  402: 'straw_hat',
#  403: 'purple_hair',
#  404: 'floating_hair',
#  405: 'battle',
#  406: 'one_side_up',
#  407: 'skirt_set',
#  408: 'bottle',
#  409: '6+girls',
#  410: 'hatsune_miku',
#  411: 'older',
#  412: 'formal',
#  413: 'bishoujo_senshi_sailor_moon',
#  414: 'tree',
#  415: 'wide_sleeves',
#  416: 'railing',
#  417: 'partially_submerged',
#  418: 'sakura_kyouko',
#  419: 'bubble',
#  420: 'pink_bow',
#  421: 'makeup',
#  422: 'chain',
#  423: 'happy_birthday',
#  424: 'food',
#  425: 'parody',
#  426: 'crescent_hair_ornament',
#  427: 'pilot_suit',
#  428: 'yukata',
#  429: 'tattoo',
#  430: 'maid_apron',
#  431: 'necklace',
#  432: 'thigh_boots',
#  433: 'corset',
#  434: 'dutch_angle',
#  435: 'pumpkin',
#  436: 'star',
#  437: 'sleeveless_dress',
#  438: 'blue',
#  439: 'nose_blush',
#  440: 'tiger_&_bunny',
#  441: 'ofuda',
#  442: 'kita_high_school_uniform',
#  443: 'expressionless',
#  444: 'lens_flare',
#  445: 'photo',
#  446: 'speech_bubble',
#  447: '6+boys',
#  448: 'strap_slip',
#  449: 'bangs',
#  450: 'cover',
#  451: 'red_scarf',
#  452: 'monogatari_(series)',
#  453: 'laughing',
#  454: 'tank_top',
#  455: 'emphasis_lines',
#  456: 'chin_rest',
#  457: 'moriya_suwako',
#  458: 'nontraditional_miko',
#  459: '!',
#  460: 'headdress',
#  461: 'feet',
#  462: 'watch',
#  463: 'horn',
#  464: 'card_(medium)',
#  465: 'stairs',
#  466: 'pov',
#  467: 'hair_bobbles',
#  468: 'tall_image',
#  469: 'turtleneck',
#  470: 'cat_tail',
#  471: 'sheath',
#  472: 'black_dress',
#  473: 'steam',
#  474: 'antennae',
#  475: 'school_swimsuit',
#  476: 'fujiwara_no_mokou',
#  477: 'jeans',
#  478: 'fingernails',
#  479: 'neckerchief',
#  480: 'cake',
#  481: 'megurine_luka',
#  482: 'bunny',
#  483: 'halloween',
#  484: 'handbag',
#  485: '/\\/\\/\\',
#  486: 'plaid',
#  487: 'toyosatomimi_no_miko',
#  488: 'bow_panties',
#  489: 'walking',
#  490: 'pants',
#  491: 'close-up',
#  492: 'adapted_costume',
#  493: 'wagashi',
#  494: 'puffy_sleeves',
#  495: ':t',
#  496: 'multiple_persona',
#  497: 'muscle',
#  498: 'cardigan',
#  499: 'multicolored_clothes',
#  500: 'character_request',
#  501: 'back-to-back',
#  502: 'lipstick',
#  503: 'long_legs',
#  504: 'brown_hair',
#  505: 'side_slit',
#  506: 'higurashi_no_naku_koro_ni',
#  507: 'fate/extra',
#  508: 'earrings',
#  509: 'casual',
#  510: 'spiked_hair',
#  511: 'pocky',
#  512: '2016',
#  513: '...',
#  514: 'cloak',
#  515: 'leg_up',
#  516: 'denim',
#  517: 'reisen_udongein_inaba',
#  518: 'thighband_pantyhose',
#  519: 'watercolor_(medium)',
#  520: 'nail_polish',
#  521: 'shorts',
#  522: 'side_ponytail',
#  523: 'hakurei_reimu',
#  524: 'white_bow',
#  525: 'contrapposto',
#  526: 'fate_(series)',
#  527: 'orange_eyes',
#  528: 'realistic',
#  529: 'green_skirt',
#  530: 'miko',
#  531: 'pokemon_sm',
#  532: 'desk',
#  533: 'star_(sky)',
#  534: 'wand',
#  535: 'aqua_hair',
#  536: 'ring',
#  537: 'interlocked_fingers',
#  538: 'wings',
#  539: 'black_footwear',
#  540: 'ass',
#  541: 'maid',
#  542: 'surprised',
#  543: 'yukkuri_shiteitte_ne',
#  544: 'drinking_glass',
#  545: 'robe',
#  546: 'silver_eyes',
#  547: 'talking',
#  548: 'greaves',
#  549: 'chopsticks',
#  550: 'flandre_scarlet',
#  551: 'torii',
#  552: 'dog',
#  553: 'mecha_musume',
#  554: 'vest',
#  555: 'kyubey',
#  556: 'flower',
#  557: 'teacup',
#  558: 'cosplay',
#  559: 'food_on_face',
#  560: 'artoria_pendragon_(all)',
#  561: 'snake',
#  562: 'goggles_on_head',
#  563: 'suzumiya_haruhi',
#  564: 'touhou_(pc-98)',
#  565: 'fantasy',
#  566: 'tainaka_ritsu',
#  567: 'fork',
#  568: 'houjuu_nue',
#  569: 'bowtie',
#  570: 'yellow_bow',
#  571: 'nude',
#  572: 'smile_precure!',
#  573: 'gym_uniform',
#  574: 'two_side_up',
#  575: 'motor_vehicle',
#  576: 'jewelry',
#  577: 'china_dress',
#  578: 'love_live!',
#  579: 'aqua_eyes',
#  580: 'cleavage_cutout',
#  581: 'demon_wings',
#  582: 'building',
#  583: 'low_ponytail',
#  584: 'spread_arms',
#  585: 'butterfly',
#  586: 'suzumiya_haruhi_no_yuuutsu',
#  587: 'touhou',
#  588: 'elbow_gloves',
#  589: 'brother_and_sister',
#  590: 'index_finger_raised',
#  591: 'sweater_vest',
#  592: 'striped_panties',
#  593: 'red_rose',
#  594: 'multicolored_hair',
#  595: '>_<',
#  596: 'underwater',
#  597: 'pelvic_curtain',
#  598: 'two-tone_hair',
#  599: 'heart',
#  600: 'full-face_blush',
#  601: 'skull',
#  602: 'red_skirt',
#  603: 'shoes',
#  604: 'nakano_azusa',
#  605: 'red_gloves',
#  606: 'clothes_writing',
#  607: 'kemono_friends',
#  608: 'shoulder_bag',
#  609: 'arms_behind_back',
#  610: 'shameimaru_aya',
#  611: 'couple',
#  612: 'standing_on_one_leg',
#  613: 'snake_hair_ornament',
#  614: 'choker',
#  615: 'ice_cream',
#  616: 'see-through',
#  617: 'fire',
#  618: 'chinese_clothes',
#  619: 'open_jacket',
#  620: 'meme_attire',
#  621: 'white_skin',
#  622: 'hand_up',
#  623: 'kagiyama_hina',
#  624: 'copyright_request',
#  625: 'otoko_no_ko',
#  626: 'half-closed_eyes',
#  627: 'single_thighhigh',
#  628: 'hair_ribbon',
#  629: 'happy',
#  630: 'page_number',
#  631: 'panties_under_pantyhose',
#  632: 'hand_in_hair',
#  633: ':q',
#  634: 'looking_back',
#  635: 'frog_hair_ornament',
#  636: 'small_breasts',
#  637: 'mystia_lorelei',
#  638: 'hair_over_shoulder',
#  639: 'ribbon',
#  640: 'headgear',
#  641: 'microphone',
#  642: 'grey_background',
#  643: 'kneeling',
#  644: 'slit_pupils',
#  645: 'flying_sweatdrops',
#  646: 'collarbone',
#  647: 'phone',
#  648: 'center_opening',
#  649: 'stuffed_animal',
#  650: 'antenna_hair',
#  651: ':>',
#  652: 'akatsuki_(kantai_collection)',
#  653: 'bat',
#  654: 'heterochromia',
#  655: 'circlet',
#  656: 'persona_4',
#  657: 'wavy_mouth',
#  658: 'under-rim_eyewear',
#  659: 'armband',
#  660: 'beard',
#  661: 'hair_bow',
#  662: 'bookshelf',
#  663: 'sketch',
#  664: 'blue_neckwear',
#  665: 'single_glove',
#  666: 'heart-shaped_pupils',
#  667: 'blue_sky',
#  668: 'curly_hair',
#  669: 'car',
#  670: 'akiyama_mio',
#  671: 'bed',
#  672: 'mahou_shoujo_madoka_magica',
#  673: 'ankle_boots',
#  674: 'bikini',
#  675: 'umbrella',
#  676: 'magical_girl',
#  677: 'jingle_bell',
#  678: 'embarrassed',
#  679: 'camera',
#  680: 'black_serafuku',
#  681: 'bare_legs',
#  682: 'alternate_color',
#  683: 'kochiya_sanae',
#  684: 'elf',
#  685: 'starry_sky',
#  686: 'turret',
#  687: 'sarashi',
#  688: '!?',
#  689: 'headwear_removed',
#  690: 'bandaid',
#  691: 'santa_hat',
#  692: "hand_on_another's_head",
#  693: 'scenery',
#  694: 'bunny_ears',
#  695: 'leotard',
#  696: 'multiple_views',
#  697: '^_^',
#  698: 'white_gloves',
#  699: 'halo',
#  700: 'ground_vehicle',
#  701: 'gochuumon_wa_usagi_desu_ka?',
#  702: 'bob_cut',
#  703: 'lace-up_boots',
#  704: 'pink_legwear',
#  705: 'blue_sailor_collar',
#  706: '@_@',
#  707: 'bed_sheet',
#  708: 'dragon',
#  709: 'sailor_collar',
#  710: 'checkered',
#  711: 'shiny',
#  712: 'gohei',
#  713: 'younger',
#  714: '4koma',
#  715: 'black_shirt',
#  716: 'haruna_(kantai_collection)',
#  717: 'ryuujou_(kantai_collection)',
#  718: 'artist_name',
#  719: 'breast_press',
#  720: 'door',
#  721: 'front_ponytail',
#  722: 'on_head',
#  723: 'covering_mouth',
#  724: 'ribbon_trim',
#  725: 'high_heels',
#  726: 'low_twintails',
#  727: 'legs_apart',
#  728: 'tatara_kogasa',
#  729: 'hitodama',
#  730: 'hair_intakes',
#  731: 'flying',
#  732: 'side-tie_bikini',
#  733: 'between_breasts',
#  734: 'sleeves_rolled_up',
#  735: 'pointy_ears',
#  736: 'white_blouse',
#  737: 'absurdres',
#  738: 'no_hat',
#  739: 'barefoot',
#  740: 'pocket',
#  741: 'daiyousei',
#  742: 'demon_tail',
#  743: 'izayoi_sakuya',
#  744: 'smoke',
#  745: 'navel',
#  746: 'skirt_lift',
#  747: 'clenched_hands',
#  748: 'spoon',
#  749: 'pantyshot',
#  750: 'looking_up',
#  751: 'short_hair',
#  752: 'flat_chest',
#  753: 'drill_hair',
#  754: 'cat_ears',
#  755: 'skindentation',
#  756: 'bra',
#  757: 'outline',
#  758: 'beach',
#  759: 'saliva',
#  760: 'wide_hips',
#  761: 'silver_hair',
#  762: 'hand_in_pocket',
#  763: 'yakumo_ran',
#  764: 'epaulettes',
#  765: 'blood',
#  766: 'one_eye_closed',
#  767: 'torpedo',
#  768: 'stomach',
#  769: 'waving',
#  770: 'strapless',
#  771: 'fox_ears',
#  772: 'inazuma_(kantai_collection)',
#  773: 'flipped_hair',
#  774: 'suit',
#  775: 'short_ponytail',
#  776: 'head_tilt',
#  777: 'from_above',
#  778: 'fox_tail',
#  779: 'sunlight',
#  780: 'rozen_maiden',
#  781: 'grin',
#  782: 'translation_request',
#  783: 'looking_away',
#  784: 'tiara',
#  785: 'fate/zero',
#  786: 'arm_support',
#  787: 'scythe',
#  788: 'blonde_hair',
#  789: 'buruma',
#  790: 'wet',
#  791: 'messy_hair',
#  792: 'blue_dress',
#  793: 'onozuka_komachi',
#  794: 'revision',
#  795: 'konpaku_youmu_(ghost)',
#  796: 'fate_testarossa',
#  797: 'sunflower',
#  798: 'chen',
#  799: 'holding_gun',
#  800: 'alice_margatroid',
#  801: 'hands_on_hips',
#  802: 'nishikino_maki',
#  803: 'stuffed_bunny',
#  804: 'lantern',
#  805: 'jumping',
#  806: 'bikini_top',
#  807: 'inaba_tewi',
#  808: 'fruit',
#  809: 'bunny_tail',
#  810: 'jpeg_artifacts',
#  811: 'cover_page',
#  812: 'dog_ears',
#  813: 'pauldrons',
#  814: 'striped_shirt',
#  815: 'fan',
#  816: 'groin',
#  817: 'neck_ribbon',
#  818: 'purple_background',
#  819: 'no_humans',
#  820: 'macross',
#  821: 'text',
#  822: 'fake_animal_ears',
#  823: 'cape',
#  824: 'box',
#  825: 'bare_arms',
#  826: 'yellow_eyes',
#  827: 'patchouli_knowledge',
#  828: 'seiza',
#  829: 'gift',
#  830: 'school_uniform',
#  831: 'hakama',
#  832: 'hat_bow',
#  833: 'dual_persona',
#  834: 'hong_meiling',
#  835: 'high_heel_boots',
#  836: '?',
#  837: 'flat_cap',
#  838: 'kaenbyou_rin',
#  839: 'black_hair',
#  840: 'monochrome',
#  841: 'third_eye',
#  842: 'bunnysuit',
#  843: '+_+',
#  844: 'jojo_no_kimyou_na_bouken',
#  845: 'armor',
#  846: 'shadow',
#  847: ':<',
#  848: 'screencap',
#  849: 'yazawa_nico',
#  850: 'peach',
#  851: 'twitter_username',
#  852: 'kimono',
#  853: 'crystal',
#  854: 'swimsuit_under_clothes',
#  855: 'hair_between_eyes',
#  856: 'white_bikini',
#  857: 'thighs',
#  858: 'headband',
#  859: 'hoodie',
#  860: 'hair_ornament',
#  861: 'arrow',
#  862: 'tea',
#  863: 'underwear',
#  864: 'kneehighs',
#  865: 'colored',
#  866: 'blue_skirt',
#  867: 'sky',
#  868: 'moon',
#  869: 'letterboxed',
#  870: 'hands_clasped',
#  871: 'mittens',
#  872: 'open_shirt',
#  873: 'large_breasts',
#  874: 'curtains',
#  875: 'face',
#  876: 'animal',
#  877: 'commentary_request',
#  878: 'green_hair',
#  879: 'northern_ocean_hime',
#  880: 'blue_legwear',
#  881: 'science_fiction',
#  882: 'toosaka_rin',
#  883: 'knees_together_feet_apart',
#  884: 'sweater',
#  885: 'legs',
#  886: 'bun_cover',
#  887: 'own_hands_together',
#  888: 'yellow_background',
#  889: 'short_shorts',
#  890: 'league_of_legends',
#  891: 'twin_braids',
#  892: 'black_skirt',
#  893: 'hair_flaps',
#  894: 'japanese_clothes',
#  895: 'wolf_tail',
#  896: 'sleeveless_shirt',
#  897: 'adjusting_clothes',
#  898: 'cup',
#  899: 'black_eyes',
#  900: 'white_ribbon',
#  901: 'obi',
#  902: 'hibiki_(kantai_collection)',
#  903: 'blue_bikini',
#  904: 'machinery',
#  905: 'duplicate',
#  906: 'black_bikini',
#  907: 'red_legwear',
#  908: 'kawashiro_nitori',
#  909: 'lowres',
#  910: 'ribbon-trimmed_sleeves',
#  911: 'cirno',
#  912: 'dark_skin',
#  913: 'ribbed_sweater',
#  914: 'brooch',
#  915: 'hair_rings',
#  916: 'doujinshi',
#  917: 'innertube',
#  918: 'transparent_background',
#  919: 'black_wings',
#  920: 'bow',
#  921: 'v',
#  922: 'shirt',
#  923: 'monster_girl',
#  924: 'smile',
#  925: 'hairband',
#  926: 'red_background',
#  927: 'sweat',
#  928: 'arm_behind_back',
#  929: 'petting',
#  930: 'translated',
#  931: 'chibi',
#  932: 'lyrical_nanoha',
#  933: 'no_panties',
#  934: 'bridal_gauntlets',
#  935: 'hetero',
#  936: 'serious',
#  937: 'open_mouth',
#  938: 'tokin_hat',
#  939: '3boys',
#  940: 'black_gloves',
#  941: 'spear',
#  942: 'head_wings',
#  943: 'motion_lines',
#  944: 'hand_on_hip',
#  945: 'bike_shorts',
#  946: 'folded_ponytail',
#  947: 'kiss',
#  948: 'crying',
#  949: 'zuikaku_(kantai_collection)',
#  950: 'twins',
#  951: 'fate/grand_order',
#  952: 'fairy_wings',
#  953: 'capelet',
#  954: 'kill_la_kill',
#  955: 'leaf',
#  956: 'looking_at_another',
#  957: 'multiple_girls',
#  958: 'music',
#  959: 'grey_eyes',
#  960: 'camisole',
#  961: 'shinkaisei-kan',
#  962: 'backlighting',
#  963: 'blanket',
#  964: 'rock',
#  965: 'very_long_hair',
#  966: 'tengen_toppa_gurren_lagann',
#  967: 'weapon',
#  968: 'braid',
#  969: 'horns',
#  970: 'jitome',
#  971: 'purple_eyes',
#  972: 'mustache',
#  973: 'semi-rimless_eyewear',
#  974: 'collared_shirt',
#  975: 'cat',
#  976: 'v-shaped_eyebrows',
#  977: 'sailor_dress',
#  978: 'buttons',
#  979: 'asymmetrical_wings',
#  980: 'salute',
#  981: 'anchor_symbol',
#  982: 'signature',
#  983: 'light_particles',
#  984: 'denim_shorts',
#  985: 'strike_witches',
#  986: 'fishnets',
#  987: 'shimakaze_(kantai_collection)',
#  988: 'pose',
#  989: 'broom',
#  990: 'reading',
#  991: 'web_address',
#  992: 'looking_to_the_side',
#  993: 'swimsuit',
#  994: 'upper_body',
#  995: 'blunt_bangs',
#  996: 'plaid_skirt',
#  997: 'multiple_boys',
#  998: 'green_dress',
#  999: 'sneakers',
#  ...}

# %%
from data.danbooru_dataset import DanbooruDataset
ds = DanbooruDataset(dfs, classes, img_data_dir, transforms=None)

# %%
img, labels = ds.__getitem__(20)

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(train_dl))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out)

# %% [markdown]
# #### Data Preparation

# %%
from data.danbooru_data_module import DanbooruDataModule

BATCH_SIZE = 64

dm = DanbooruDataModule(
    img_data_dir+'image_subset_metadata.pkl',
    img_data_dir,
    subsample=50000,
    min_support=1000,
    batch_size=BATCH_SIZE,
    num_workers=12)

# %%
dm.setup()
# Out:
# 10 top tags:
# ('1girl', 32750)
# ('solo', 28658)
# ('long_hair', 21902)
# ('highres', 16880)
# ('smile', 14962)
# ('short_hair', 14176)
# ('multiple_girls', 12272)
# ('blush', 11758)
# ('touhou', 10835)
# ('open_mouth', 10529)
# Dictionary contains 188 tags.

# %%
dm.num_classes
# Out:
# 188

# %% [markdown]
# ### Models

# %%
import torch
import torch.nn.functional as F
import pytorch_lightning as pl

from torch.optim.lr_scheduler import OneCycleLR
from torchmetrics.functional import accuracy, precision
import torchmetrics.functional as tf
from pytorch_lightning.loggers import WandbLogger
from pytorch_lightning.callbacks import TQDMProgressBar

# %%
class ResNetMultiLabel(nn.Module):
    def __init__(self, model, n_classes):
        super().__init__()
        resnet = model
        resnet.fc = nn.Sequential(
            nn.Dropout(p=0.2),
            nn.Linear(in_features=resnet.fc.in_features, out_features=n_classes)
        )
        self.backbone = resnet
        #self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        
        out = self.backbone(x)
        
        return out

# %%
class ResNetMultiTrainModule(pl.LightningModule):
    def __init__(self, model, model_desc, batch_size, learning_rate, momentum, n_classes, thresh=0.5):
        super().__init__()

        # Key parameters
        self.save_hyperparameters()

        self.model = ResNetMultiLabel(model, n_classes)

    def forward(self, x):
        x = self.model(x)        
        return x

    def evaluate(self, batch, stage=None):
        x, y = batch
        y_hat = self(x)
        loss = F.binary_cross_entropy_with_logits(y_hat, y.type(torch.float))
        acc = accuracy(y_hat, y.type(torch.int), threshold=self.hparams.thresh)
        prec = precision(y_hat, y.type(torch.int), threshold=self.hparams.thresh)
        recall = tf.recall(y_hat, y.type(torch.int), threshold=self.hparams.thresh)
        f1_score = tf.f1_score(y_hat, y.type(torch.int), threshold=self.hparams.thresh)
        rmap = tf.retrieval_average_precision(y_hat, y.type(torch.int))

        if stage:
            self.log(f"{stage}_loss", loss, prog_bar=True)
            self.log(f"{stage}_acc", acc, prog_bar=True)
            self.log(f"{stage}_prec", prec, prog_bar=True)
            self.log(f"{stage}_recall", recall, prog_bar=True)
            self.log(f"{stage}_f1_score", f1_score, prog_bar=True)
            self.log(f"{stage}_rmap", rmap, prog_bar=True)
    
    def training_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self(x)
        loss = F.binary_cross_entropy_with_logits(y_hat, y.type(torch.float))
        self.log("train_loss", loss)
        return loss

    def validation_step(self, batch, batch_idx):
        self.evaluate(batch, "val")

    def test_step(self, batch, batch_idx):
        self.evaluate(batch, "test")

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(
            self.parameters(), 
            lr=self.hparams.learning_rate,
            betas=(0.9,0.999))
        #optimizer = torch.optim.SGD(self.parameters(), lr=self.hparams.learning_rate, momentum=self.hparams.momentum)
        
        # steps_per_epoch = 60000 // self.hparams.batch_size
        # '''
        # lr_scheduler_dict = {
        #     "scheduler":MultiStepLR(optimizer, milestones=[100, 150], gamma=0.1)
        # }
        # '''
        # lr_scheduler_dict = {
        #     "scheduler":OneCycleLR(
        #         optimizer,
        #         self.hparams.learning_rate,
        #         epochs=self.trainer.max_epochs,
        #         steps_per_epoch=steps_per_epoch,
        #         anneal_strategy='cos'
        #     ),
        #     "interval":"step",
        # }
        #return {"optimizer":optimizer, "lr_scheduler":lr_scheduler_dict}
        return optimizer

# %%
pl_model = ResNetMultiTrainModule(
    models.resnet50(pretrained=True),
    model_desc="resnet50",
    batch_size=BATCH_SIZE, 
    learning_rate=0.001, 
    momentum=0.9, 
    n_classes=dm.num_classes)
# Out:
# /home/curttigges/miniconda3/envs/pytorch-dl/lib/python3.7/site-packages/pytorch_lightning/utilities/parsing.py:262: UserWarning: Attribute 'model' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['model'])`.
#   f"Attribute {k!r} is an instance of `nn.Module` and is already saved during checkpointing."

# %%
wandb_logger = WandbLogger(project="resnet-danbooru")
wandb_logger.watch(pl_model, log="all")

trainer = pl.Trainer(
    max_epochs=10,
    precision=16,
    accelerator='gpu', 
    devices=1,
    logger=wandb_logger,
    profiler="simple",
    callbacks=[TQDMProgressBar(refresh_rate=10)])
trainer.fit(pl_model, dm)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: curt-tigges (ascendant). Use `wandb login --relogin` to force relogin
# wandb version 0.12.18 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.17
# Run data is saved locally in <code>/home/curttigges/projects/query2label/wandb/run-20220611_171529-1c821mg0</code>
# Syncing run <strong><a href="https://wandb.ai/ascendant/resnet-danbooru/runs/1c821mg0" target="_blank">winter-snowball-12</a></strong> to <a href="https://wandb.ai/ascendant/resnet-danbooru" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb: logging graph, to disable use `wandb.watch(log_graph=False)`
# Using 16bit native Automatic Mixed Precision (AMP)
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# 10 top tags:
# ('1girl', 32750)
# ('solo', 28658)
# ('long_hair', 21902)
# ('highres', 16880)
# ('smile', 14962)
# ('short_hair', 14176)
# ('multiple_girls', 12272)
# ('blush', 11758)
# ('touhou', 10835)
# ('open_mouth', 10529)
# Dictionary contains 188 tags.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type             | Params
# -------------------------------------------
# 0 | model | ResNetMultiLabel | 23.9 M
# -------------------------------------------
# 23.9 M    Trainable params
# 0         Non-trainable params
# 23.9 M    Total params
# 47.786    Total estimated model params size (MB)
# Epoch 9: 100%|██████████| 692/692 [26:20<00:00,  2.28s/it, loss=0.219, v_num=1mg0, val_loss=0.268, val_acc=0.928, val_prec=0.624, val_recall=0.0606, val_f1_score=0.110, val_rmap=0.262]
# FIT Profiler Report
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                                                                                                                                                                    	|  Mean duration (s)	|  Num calls      	|  Total time (s) 	|  Percentage %   	|
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                                                                                                                                                                     	|  -              	|  113007         	|  1603.1         	|  100 %          	|
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  run_training_epoch                                                                                                                                                                                        	|  157.7          	|  10             	|  1577.0         	|  98.374         	|
# |  [Strategy]SingleDeviceStrategy.validation_step                                                                                                                                                            	|  0.15647        	|  6352           	|  993.91         	|  62.001         	|
# |  [Strategy]SingleDeviceStrategy.batch_to_device                                                                                                                                                            	|  0.027108       	|  6922           	|  187.64         	|  11.705         	|
# |  run_training_batch                                                                                                                                                                                        	|  0.32732        	|  570            	|  186.57         	|  11.638         	|
# |  [LightningModule]ResNetMultiTrainModule.optimizer_step                                                                                                                                                    	|  0.32691        	|  570            	|  186.34         	|  11.624         	|
# |  [Strategy]SingleDeviceStrategy.backward                                                                                                                                                                   	|  0.060108       	|  570            	|  34.262         	|  2.1373         	|
# |  [Strategy]SingleDeviceStrategy.training_step                                                                                                                                                              	|  0.014207       	|  570            	|  8.0982         	|  0.50517        	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_train_epoch_end                 	|  0.3644         	|  10             	|  3.644          	|  0.22732        	|
# |  [Callback]TQDMProgressBar.on_validation_batch_end                                                                                                                                                         	|  0.00019449     	|  6352           	|  1.2354         	|  0.077067       	|
# |  [LightningModule]ResNetMultiTrainModule.optimizer_zero_grad                                                                                                                                               	|  0.00077194     	|  570            	|  0.44001        	|  0.027448       	|
# |  on_train_batch_end                                                                                                                                                                                        	|  0.00024713     	|  570            	|  0.14086        	|  0.0087871      	|
# |  [Callback]TQDMProgressBar.on_validation_batch_start                                                                                                                                                       	|  1.7015e-05     	|  6352           	|  0.10808        	|  0.006742       	|
# |  on_train_batch_start                                                                                                                                                                                      	|  8.097e-05      	|  570            	|  0.046153       	|  0.0028791      	|
# |  [Callback]ModelSummary.on_validation_batch_end                                                                                                                                                            	|  3.0274e-06     	|  6352           	|  0.01923        	|  0.0011996      	|
# |  [Callback]ModelSummary.on_validation_batch_start                                                                                                                                                          	|  2.8509e-06     	|  6352           	|  0.018109       	|  0.0011297      	|
# |  [Callback]TQDMProgressBar.on_validation_end                                                                                                                                                               	|  0.0012078      	|  11             	|  0.013286       	|  0.0008288      	|
# |  [Callback]TQDMProgressBar.on_validation_start                                                                                                                                                             	|  0.0010911      	|  11             	|  0.012002       	|  0.00074868     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_batch_start          	|  1.7891e-06     	|  6352           	|  0.011364       	|  0.00070892     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_batch_end            	|  1.7319e-06     	|  6352           	|  0.011001       	|  0.00068624     	|
# |  [Callback]GradientAccumulationScheduler.on_validation_batch_start                                                                                                                                         	|  1.7195e-06     	|  6352           	|  0.010922       	|  0.00068133     	|
# |  [LightningModule]ResNetMultiTrainModule.validation_step_end                                                                                                                                               	|  1.6773e-06     	|  6352           	|  0.010654       	|  0.0006646      	|
# |  [Callback]GradientAccumulationScheduler.on_validation_batch_end                                                                                                                                           	|  1.646e-06      	|  6352           	|  0.010456       	|  0.00065222     	|
# |  [LightningModule]ResNetMultiTrainModule.on_validation_batch_start                                                                                                                                         	|  1.5953e-06     	|  6352           	|  0.010133       	|  0.00063213     	|
# |  [LightningModule]ResNetMultiTrainModule.on_validation_batch_end                                                                                                                                           	|  1.3733e-06     	|  6352           	|  0.0087235      	|  0.00054418     	|
# |  [LightningModule]ResNetMultiTrainModule.on_validation_model_train                                                                                                                                         	|  0.00058405     	|  11             	|  0.0064246      	|  0.00040077     	|
# |  [Strategy]SingleDeviceStrategy.validation_step_end                                                                                                                                                        	|  9.8047e-07     	|  6352           	|  0.0062279      	|  0.0003885      	|
# |  [Callback]TQDMProgressBar.on_train_epoch_start                                                                                                                                                            	|  0.00061985     	|  10             	|  0.0061985      	|  0.00038666     	|
# |  [LightningModule]ResNetMultiTrainModule.on_validation_model_eval                                                                                                                                          	|  0.0005022      	|  11             	|  0.0055242      	|  0.0003446      	|
# |  [Callback]TQDMProgressBar.on_train_epoch_end                                                                                                                                                              	|  0.00042193     	|  10             	|  0.0042193      	|  0.0002632      	|
# |  [Callback]TQDMProgressBar.on_after_backward                                                                                                                                                               	|  5.4488e-06     	|  570            	|  0.0031058      	|  0.00019374     	|
# |  [Callback]ModelSummary.on_fit_start                                                                                                                                                                       	|  0.0028811      	|  1              	|  0.0028811      	|  0.00017973     	|
# |  [Callback]TQDMProgressBar.on_batch_start                                                                                                                                                                  	|  4.2345e-06     	|  570            	|  0.0024136      	|  0.00015056     	|
# |  [Callback]TQDMProgressBar.on_before_optimizer_step                                                                                                                                                        	|  3.9272e-06     	|  570            	|  0.0022385      	|  0.00013964     	|
# |  [Callback]TQDMProgressBar.on_before_zero_grad                                                                                                                                                             	|  3.0991e-06     	|  570            	|  0.0017665      	|  0.00011019     	|
# |  [Callback]ModelSummary.on_after_backward                                                                                                                                                                  	|  3.077e-06      	|  570            	|  0.0017539      	|  0.00010941     	|
# |  [Callback]TQDMProgressBar.on_before_backward                                                                                                                                                              	|  2.7154e-06     	|  570            	|  0.0015478      	|  9.6551e-05     	|
# |  [Callback]TQDMProgressBar.on_sanity_check_start                                                                                                                                                           	|  0.0015368      	|  1              	|  0.0015368      	|  9.5864e-05     	|
# |  [Callback]TQDMProgressBar.on_batch_end                                                                                                                                                                    	|  2.2601e-06     	|  570            	|  0.0012883      	|  8.0363e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_after_backward                  	|  2.2529e-06     	|  570            	|  0.0012841      	|  8.0106e-05     	|
# |  [Callback]ModelSummary.on_before_optimizer_step                                                                                                                                                           	|  2.1305e-06     	|  570            	|  0.0012144      	|  7.5756e-05     	|
# |  [Callback]ModelSummary.on_batch_start                                                                                                                                                                     	|  2.1061e-06     	|  570            	|  0.0012005      	|  7.4888e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_after_backward                                                                                                                                                 	|  2.0831e-06     	|  570            	|  0.0011874      	|  7.407e-05      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_batch_start                     	|  1.8047e-06     	|  570            	|  0.0010287      	|  6.4169e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_before_optimizer_step                                                                                                                                          	|  1.7973e-06     	|  570            	|  0.0010245      	|  6.3908e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_before_optimizer_step           	|  1.7687e-06     	|  570            	|  0.0010082      	|  6.2891e-05     	|
# |  [Callback]ModelSummary.on_before_zero_grad                                                                                                                                                                	|  1.7065e-06     	|  570            	|  0.00097268     	|  6.0677e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_before_zero_grad                	|  1.6647e-06     	|  570            	|  0.00094888     	|  5.9192e-05     	|
# |  [Callback]ModelSummary.on_before_backward                                                                                                                                                                 	|  1.6608e-06     	|  570            	|  0.00094667     	|  5.9054e-05     	|
# |  [Callback]TQDMProgressBar.on_train_start                                                                                                                                                                  	|  0.00093061     	|  1              	|  0.00093061     	|  5.8052e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_batch_start                                                                                                                                                    	|  1.6085e-06     	|  570            	|  0.00091682     	|  5.7192e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_batch_end                       	|  1.5939e-06     	|  570            	|  0.00090851     	|  5.6673e-05     	|
# |  [Callback]ModelSummary.on_batch_end                                                                                                                                                                       	|  1.5765e-06     	|  570            	|  0.00089862     	|  5.6057e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_before_backward                 	|  1.5743e-06     	|  570            	|  0.00089735     	|  5.5977e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_batch_end                                                                                                                                                      	|  1.5031e-06     	|  570            	|  0.00085675     	|  5.3445e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_before_zero_grad                                                                                                                                               	|  1.4848e-06     	|  570            	|  0.00084634     	|  5.2795e-05     	|
# |  [LightningModule]ResNetMultiTrainModule.on_after_backward                                                                                                                                                 	|  1.4551e-06     	|  570            	|  0.00082942     	|  5.174e-05      	|
# |  [LightningModule]ResNetMultiTrainModule.training_step_end                                                                                                                                                 	|  1.4385e-06     	|  570            	|  0.00081992     	|  5.1147e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_before_backward                                                                                                                                                	|  1.4324e-06     	|  570            	|  0.00081645     	|  5.0931e-05     	|
# |  [LightningModule]ResNetMultiTrainModule.on_train_batch_end                                                                                                                                                	|  1.3975e-06     	|  570            	|  0.00079658     	|  4.9691e-05     	|
# |  [LightningModule]ResNetMultiTrainModule.on_before_zero_grad                                                                                                                                               	|  1.3626e-06     	|  570            	|  0.00077669     	|  4.845e-05      	|
# |  [LightningModule]ResNetMultiTrainModule.on_train_batch_start                                                                                                                                              	|  1.3542e-06     	|  570            	|  0.00077189     	|  4.8151e-05     	|
# |  [Strategy]SingleDeviceStrategy.on_train_batch_start                                                                                                                                                       	|  1.1989e-06     	|  570            	|  0.00068335     	|  4.2628e-05     	|
# |  [LightningModule]ResNetMultiTrainModule.on_before_optimizer_step                                                                                                                                          	|  1.1308e-06     	|  570            	|  0.00064454     	|  4.0207e-05     	|
# |  [Callback]TQDMProgressBar.on_train_end                                                                                                                                                                    	|  0.00063244     	|  1              	|  0.00063244     	|  3.9452e-05     	|
# |  [Strategy]SingleDeviceStrategy.training_step_end                                                                                                                                                          	|  1.0769e-06     	|  570            	|  0.00061386     	|  3.8293e-05     	|
# |  [LightningModule]ResNetMultiTrainModule.on_before_backward                                                                                                                                                	|  1.0745e-06     	|  570            	|  0.00061247     	|  3.8206e-05     	|
# |  [LightningModule]ResNetMultiTrainModule.configure_optimizers                                                                                                                                              	|  0.00046704     	|  1              	|  0.00046704     	|  2.9134e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_end                  	|  3.411e-05      	|  11             	|  0.00037522     	|  2.3406e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': None}.setup                              	|  0.00017769     	|  1              	|  0.00017769     	|  1.1085e-05     	|
# |  [Callback]ModelSummary.on_validation_start                                                                                                                                                                	|  6.408e-06      	|  11             	|  7.0488e-05     	|  4.3971e-06     	|
# |  [Callback]TQDMProgressBar.on_epoch_start                                                                                                                                                                  	|  3.2207e-06     	|  21             	|  6.7634e-05     	|  4.219e-06      	|
# |  [Callback]ModelSummary.on_train_epoch_end                                                                                                                                                                 	|  5.613e-06      	|  10             	|  5.613e-05      	|  3.5014e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_train_epoch_start                                                                                                                                              	|  5.2956e-06     	|  10             	|  5.2956e-05     	|  3.3034e-06     	|
# |  [Callback]ModelSummary.on_validation_end                                                                                                                                                                  	|  4.619e-06      	|  11             	|  5.0809e-05     	|  3.1695e-06     	|
# |  [Callback]TQDMProgressBar.on_epoch_end                                                                                                                                                                    	|  2.3341e-06     	|  21             	|  4.9016e-05     	|  3.0576e-06     	|
# |  [Callback]ModelSummary.on_train_epoch_start                                                                                                                                                               	|  4.3566e-06     	|  10             	|  4.3566e-05     	|  2.7177e-06     	|
# |  [LightningModule]ResNetMultiTrainModule.on_epoch_start                                                                                                                                                    	|  2.0396e-06     	|  21             	|  4.2832e-05     	|  2.6719e-06     	|
# |  [LightningModule]ResNetMultiTrainModule.on_validation_epoch_start                                                                                                                                         	|  3.4549e-06     	|  11             	|  3.8004e-05     	|  2.3707e-06     	|
# |  [LightningModule]ResNetMultiTrainModule.on_validation_epoch_end                                                                                                                                           	|  3.4082e-06     	|  11             	|  3.749e-05      	|  2.3386e-06     	|
# |  [Callback]ModelSummary.on_epoch_start                                                                                                                                                                     	|  1.593e-06      	|  21             	|  3.3453e-05     	|  2.0868e-06     	|
# |  [Callback]TQDMProgressBar.on_save_checkpoint                                                                                                                                                              	|  3.2925e-06     	|  10             	|  3.2925e-05     	|  2.0539e-06     	|
# |  [LightningModule]ResNetMultiTrainModule.on_validation_start                                                                                                                                               	|  2.9895e-06     	|  11             	|  3.2885e-05     	|  2.0514e-06     	|
# |  [Callback]ModelSummary.on_epoch_end                                                                                                                                                                       	|  1.5606e-06     	|  21             	|  3.2773e-05     	|  2.0444e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_epoch_end                       	|  1.5388e-06     	|  21             	|  3.2314e-05     	|  2.0158e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_epoch_start                     	|  1.5334e-06     	|  21             	|  3.2202e-05     	|  2.0088e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_end                                                                                                                                                          	|  2.8384e-06     	|  11             	|  3.1222e-05     	|  1.9476e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_epoch_start                                                                                                                                                    	|  1.4323e-06     	|  21             	|  3.0079e-05     	|  1.8763e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_epoch_end                                                                                                                                                      	|  1.4143e-06     	|  21             	|  2.97e-05       	|  1.8527e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_start                                                                                                                                                        	|  2.6642e-06     	|  11             	|  2.9306e-05     	|  1.8281e-06     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_end                                                                                                                                                         	|  2.4885e-06     	|  11             	|  2.7373e-05     	|  1.7075e-06     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_start                                                                                                                                                       	|  2.0101e-06     	|  11             	|  2.2111e-05     	|  1.3793e-06     	|
# |  [Callback]ModelSummary.on_save_checkpoint                                                                                                                                                                 	|  2.2072e-06     	|  10             	|  2.2072e-05     	|  1.3769e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_validation_end                                                                                                                                                 	|  1.9947e-06     	|  11             	|  2.1942e-05     	|  1.3688e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_validation_start                                                                                                                                               	|  1.9913e-06     	|  11             	|  2.1904e-05     	|  1.3664e-06     	|
# |  [LightningModule]ResNetMultiTrainModule.on_epoch_end                                                                                                                                                      	|  1.0005e-06     	|  21             	|  2.1011e-05     	|  1.3107e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_save_checkpoint                                                                                                                                                	|  1.9908e-06     	|  10             	|  1.9908e-05     	|  1.2419e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_train_epoch_end                                                                                                                                                	|  1.9679e-06     	|  10             	|  1.9679e-05     	|  1.2276e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_start                	|  1.7798e-06     	|  11             	|  1.9578e-05     	|  1.2213e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_epoch_end            	|  1.7398e-06     	|  11             	|  1.9138e-05     	|  1.1938e-06     	|
# |  [Callback]ModelSummary.on_validation_epoch_end                                                                                                                                                            	|  1.6623e-06     	|  11             	|  1.8285e-05     	|  1.1406e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_train_epoch_start               	|  1.8285e-06     	|  10             	|  1.8285e-05     	|  1.1406e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_save_checkpoint                 	|  1.7374e-06     	|  10             	|  1.7374e-05     	|  1.0838e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_validation_epoch_end                                                                                                                                           	|  1.5723e-06     	|  11             	|  1.7295e-05     	|  1.0789e-06     	|
# |  [LightningModule]ResNetMultiTrainModule.on_train_epoch_end                                                                                                                                                	|  1.6332e-06     	|  10             	|  1.6332e-05     	|  1.0188e-06     	|
# |  [Callback]ModelSummary.on_validation_epoch_start                                                                                                                                                          	|  1.4401e-06     	|  11             	|  1.5841e-05     	|  9.8817e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_epoch_start          	|  1.4293e-06     	|  11             	|  1.5722e-05     	|  9.8075e-07     	|
# |  [Callback]GradientAccumulationScheduler.on_validation_epoch_start                                                                                                                                         	|  1.3863e-06     	|  11             	|  1.5249e-05     	|  9.5124e-07     	|
# |  [LightningModule]ResNetMultiTrainModule.validation_epoch_end                                                                                                                                              	|  1.3754e-06     	|  11             	|  1.5129e-05     	|  9.4376e-07     	|
# |  [LightningModule]ResNetMultiTrainModule.on_validation_end                                                                                                                                                 	|  1.2862e-06     	|  11             	|  1.4148e-05     	|  8.8256e-07     	|
# |  [LightningModule]ResNetMultiTrainModule.on_save_checkpoint                                                                                                                                                	|  1.1575e-06     	|  10             	|  1.1575e-05     	|  7.2206e-07     	|
# |  [LightningModule]ResNetMultiTrainModule.on_train_epoch_start                                                                                                                                              	|  9.177e-07      	|  10             	|  9.177e-06      	|  5.7247e-07     	|
# |  [Callback]TQDMProgressBar.setup                                                                                                                                                                           	|  8.246e-06      	|  1              	|  8.246e-06      	|  5.1439e-07     	|
# |  [Callback]ModelSummary.on_train_end                                                                                                                                                                       	|  5.421e-06      	|  1              	|  5.421e-06      	|  3.3817e-07     	|
# |  [Callback]TQDMProgressBar.on_fit_end                                                                                                                                                                      	|  5e-06          	|  1              	|  5e-06          	|  3.119e-07      	|
# |  [Callback]ModelSummary.on_sanity_check_start                                                                                                                                                              	|  4.628e-06      	|  1              	|  4.628e-06      	|  2.887e-07      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_sanity_check_end                	|  4.619e-06      	|  1              	|  4.619e-06      	|  2.8814e-07     	|
# |  [Callback]GradientAccumulationScheduler.on_fit_start                                                                                                                                                      	|  4.578e-06      	|  1              	|  4.578e-06      	|  2.8558e-07     	|
# |  [Callback]TQDMProgressBar.on_pretrain_routine_start                                                                                                                                                       	|  4.518e-06      	|  1              	|  4.518e-06      	|  2.8184e-07     	|
# |  [Callback]TQDMProgressBar.on_sanity_check_end                                                                                                                                                             	|  4.178e-06      	|  1              	|  4.178e-06      	|  2.6063e-07     	|
# |  [LightningModule]ResNetMultiTrainModule.configure_callbacks                                                                                                                                               	|  4.057e-06      	|  1              	|  4.057e-06      	|  2.5308e-07     	|
# |  [Callback]ModelSummary.on_train_start                                                                                                                                                                     	|  4.047e-06      	|  1              	|  4.047e-06      	|  2.5245e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_train_start                     	|  3.928e-06      	|  1              	|  3.928e-06      	|  2.4503e-07     	|
# |  [LightningModule]ResNetMultiTrainModule.on_train_start                                                                                                                                                    	|  3.246e-06      	|  1              	|  3.246e-06      	|  2.0249e-07     	|
# |  [Callback]TQDMProgressBar.on_fit_start                                                                                                                                                                    	|  3.095e-06      	|  1              	|  3.095e-06      	|  1.9307e-07     	|
# |  [Callback]ModelSummary.setup                                                                                                                                                                              	|  2.695e-06      	|  1              	|  2.695e-06      	|  1.6812e-07     	|
# |  [Callback]TQDMProgressBar.teardown                                                                                                                                                                        	|  2.666e-06      	|  1              	|  2.666e-06      	|  1.6631e-07     	|
# |  [Callback]TQDMProgressBar.on_before_accelerator_backend_setup                                                                                                                                             	|  2.554e-06      	|  1              	|  2.554e-06      	|  1.5932e-07     	|
# |  [Callback]ModelSummary.on_sanity_check_end                                                                                                                                                                	|  2.335e-06      	|  1              	|  2.335e-06      	|  1.4566e-07     	|
# |  [Callback]ModelSummary.on_pretrain_routine_start                                                                                                                                                          	|  2.104e-06      	|  1              	|  2.104e-06      	|  1.3125e-07     	|
# |  [Callback]TQDMProgressBar.on_pretrain_routine_end                                                                                                                                                         	|  2.094e-06      	|  1              	|  2.094e-06      	|  1.3063e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_sanity_check_start              	|  2.034e-06      	|  1              	|  2.034e-06      	|  1.2688e-07     	|
# |  [Callback]TQDMProgressBar.on_configure_sharded_model                                                                                                                                                      	|  2.034e-06      	|  1              	|  2.034e-06      	|  1.2688e-07     	|
# |  [Callback]GradientAccumulationScheduler.on_sanity_check_start                                                                                                                                             	|  2.014e-06      	|  1              	|  2.014e-06      	|  1.2563e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_pretrain_routine_start          	|  2.013e-06      	|  1              	|  2.013e-06      	|  1.2557e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_pretrain_routine_end            	|  1.984e-06      	|  1              	|  1.984e-06      	|  1.2376e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_fit_start                       	|  1.874e-06      	|  1              	|  1.874e-06      	|  1.169e-07      	|
# |  [LightningModule]ResNetMultiTrainModule.prepare_data                                                                                                                                                      	|  1.823e-06      	|  1              	|  1.823e-06      	|  1.1372e-07     	|
# |  [Callback]GradientAccumulationScheduler.on_pretrain_routine_start                                                                                                                                         	|  1.784e-06      	|  1              	|  1.784e-06      	|  1.1129e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': None}.on_before_accelerator_backend_setup	|  1.783e-06      	|  1              	|  1.783e-06      	|  1.1122e-07     	|
# |  [Callback]GradientAccumulationScheduler.on_train_start                                                                                                                                                    	|  1.783e-06      	|  1              	|  1.783e-06      	|  1.1122e-07     	|
# |  [Callback]ModelSummary.on_fit_end                                                                                                                                                                         	|  1.773e-06      	|  1              	|  1.773e-06      	|  1.106e-07      	|
# |  [LightningModule]ResNetMultiTrainModule.on_pretrain_routine_start                                                                                                                                         	|  1.743e-06      	|  1              	|  1.743e-06      	|  1.0873e-07     	|
# |  [Callback]ModelSummary.on_pretrain_routine_end                                                                                                                                                            	|  1.703e-06      	|  1              	|  1.703e-06      	|  1.0623e-07     	|
# |  [LightningModule]ResNetMultiTrainModule.setup                                                                                                                                                             	|  1.674e-06      	|  1              	|  1.674e-06      	|  1.0443e-07     	|
# |  [Callback]GradientAccumulationScheduler.on_train_end                                                                                                                                                      	|  1.664e-06      	|  1              	|  1.664e-06      	|  1.038e-07      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_train_end                       	|  1.653e-06      	|  1              	|  1.653e-06      	|  1.0311e-07     	|
# |  [Callback]GradientAccumulationScheduler.on_pretrain_routine_end                                                                                                                                           	|  1.633e-06      	|  1              	|  1.633e-06      	|  1.0187e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_fit_end                         	|  1.613e-06      	|  1              	|  1.613e-06      	|  1.0062e-07     	|
# |  [Callback]ModelSummary.on_before_accelerator_backend_setup                                                                                                                                                	|  1.553e-06      	|  1              	|  1.553e-06      	|  9.6877e-08     	|
# |  [Callback]GradientAccumulationScheduler.setup                                                                                                                                                             	|  1.553e-06      	|  1              	|  1.553e-06      	|  9.6877e-08     	|
# |  [Callback]ModelSummary.on_configure_sharded_model                                                                                                                                                         	|  1.523e-06      	|  1              	|  1.523e-06      	|  9.5005e-08     	|
# |  [Callback]GradientAccumulationScheduler.on_sanity_check_end                                                                                                                                               	|  1.503e-06      	|  1              	|  1.503e-06      	|  9.3759e-08     	|
# |  [LightningModule]ResNetMultiTrainModule.on_fit_end                                                                                                                                                        	|  1.503e-06      	|  1              	|  1.503e-06      	|  9.3758e-08     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.teardown                           	|  1.503e-06      	|  1              	|  1.503e-06      	|  9.3758e-08     	|
# |  [Callback]ModelSummary.teardown                                                                                                                                                                           	|  1.473e-06      	|  1              	|  1.473e-06      	|  9.1887e-08     	|
# |  [LightningModule]ResNetMultiTrainModule.on_train_end                                                                                                                                                      	|  1.463e-06      	|  1              	|  1.463e-06      	|  9.1263e-08     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_configure_sharded_model         	|  1.453e-06      	|  1              	|  1.453e-06      	|  9.064e-08      	|
# |  [Callback]GradientAccumulationScheduler.on_before_accelerator_backend_setup                                                                                                                               	|  1.433e-06      	|  1              	|  1.433e-06      	|  8.9391e-08     	|
# |  [Callback]GradientAccumulationScheduler.on_fit_end                                                                                                                                                        	|  1.383e-06      	|  1              	|  1.383e-06      	|  8.6272e-08     	|
# |  [Callback]GradientAccumulationScheduler.teardown                                                                                                                                                          	|  1.372e-06      	|  1              	|  1.372e-06      	|  8.5586e-08     	|
# |  [Callback]GradientAccumulationScheduler.on_configure_sharded_model                                                                                                                                        	|  1.343e-06      	|  1              	|  1.343e-06      	|  8.3777e-08     	|
# |  [LightningModule]ResNetMultiTrainModule.on_train_dataloader                                                                                                                                               	|  1.333e-06      	|  1              	|  1.333e-06      	|  8.3153e-08     	|
# |  [LightningModule]ResNetMultiTrainModule.on_val_dataloader                                                                                                                                                 	|  1.273e-06      	|  1              	|  1.273e-06      	|  7.9411e-08     	|
# |  [LightningModule]ResNetMultiTrainModule.on_fit_start                                                                                                                                                      	|  1.223e-06      	|  1              	|  1.223e-06      	|  7.6291e-08     	|
# |  [Strategy]SingleDeviceStrategy.on_train_end                                                                                                                                                               	|  1.152e-06      	|  1              	|  1.152e-06      	|  7.1863e-08     	|
# |  [LightningModule]ResNetMultiTrainModule.configure_sharded_model                                                                                                                                           	|  1.152e-06      	|  1              	|  1.152e-06      	|  7.1862e-08     	|
# |  [Strategy]SingleDeviceStrategy.on_train_start                                                                                                                                                             	|  9.02e-07       	|  1              	|  9.02e-07       	|  5.6267e-08     	|
# |  [LightningModule]ResNetMultiTrainModule.on_pretrain_routine_end                                                                                                                                           	|  8.8201e-07     	|  1              	|  8.8201e-07     	|  5.502e-08      	|
# |  [LightningModule]ResNetMultiTrainModule.teardown                                                                                                                                                          	|  7.0201e-07     	|  1              	|  7.0201e-07     	|  4.3792e-08     	|
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
