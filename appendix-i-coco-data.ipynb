# %%
from q2l_labeller.data.coco_dataset import CoCoDataset
from PIL import Image

# %%
img_dir = "/media/curttigges/project-files/datasets/ms-coco/images/val2014/"
anno_path = "/media/curttigges/project-files/datasets/ms-coco/annotations/instances_val2014.json"
labels_path = "/media/curttigges/project-files/datasets/ms-coco/annotations/labels_val2014.npy"
ccd = CoCoDataset(image_dir=str(img_dir), anno_path=anno_path, labels_path=labels_path)
# Out:
# loading annotations into memory...
# Done (t=3.91s)
# creating index...
# index created!

# %%
item = ccd.__getitem__(5)

# %%
item[1].size
# Out:
# 80

# %%
item[0]
# Out:
# <PIL.Image.Image image mode=RGB size=640x426 at 0x7F8D7C4887D0>
